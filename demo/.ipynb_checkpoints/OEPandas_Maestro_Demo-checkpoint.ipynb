# %%
import cnotebook
import oepandas as oepd
from openeye import oechem

# %% [markdown]
# # Using OEPandas with Maestro Formats
#
# This only requires a valid OpenEye Toolkit license. You do not need to have any Schrodinger software installed.
#
# <div class="alert alert-block alert-info">
#     <b>As long as you have <tt>oepandas</tt> installed, you don't need to do anything special!</b>
# </dev>

# %%
df = oepd.read_mae("../tests/assets/5.maegz")
df.head()
# Out:
#                                             Molecule          Title  \
# 0  <oechem.OEMol; proxy of <Swig Object of type '...        Aspirin
# 1  <oechem.OEMol; proxy of <Swig Object of type '...      Ibuprofen
# 2  <oechem.OEMol; proxy of <Swig Object of type '...  Acetaminophen
# 3  <oechem.OEMol; proxy of <Swig Object of type '...       Caffeine
# 4  <oechem.OEMol; proxy of <Swig Object of type '...       Diazepam
#
#    Chiralities_Consistent  chiral_flag  mmshare_version  ct_format  \
# 0                       1            0            73163          2
# 1                       1            1            73163          2
# 2                       1            0            73163          2
# 3                       1            0            73163          2
# 4                       1            0            73163          2
#
#    ct_stereo_status  source_file_index  NumAcceptors  NumDonors     Energy  \
# ...

# %% [markdown]
# The molecules are regular OpenEye molecules, so you can use them in the standard ``oepandas``/``cnotebook`` way:

# %%
df["NumCarbons"] = df.Molecule.apply(lambda x: oechem.OECount(x, oechem.OEIsCarbon()))

# Display the table
df.head()
# Out:
#                                             Molecule          Title  \
# 0  <oechem.OEMol; proxy of <Swig Object of type '...        Aspirin
# 1  <oechem.OEMol; proxy of <Swig Object of type '...      Ibuprofen
# 2  <oechem.OEMol; proxy of <Swig Object of type '...  Acetaminophen
# 3  <oechem.OEMol; proxy of <Swig Object of type '...       Caffeine
# 4  <oechem.OEMol; proxy of <Swig Object of type '...       Diazepam
#
#    Chiralities_Consistent  chiral_flag  mmshare_version  ct_format  \
# 0                       1            0            73163          2
# 1                       1            1            73163          2
# 2                       1            0            73163          2
# 3                       1            0            73163          2
# 4                       1            0            73163          2
#
#    ct_stereo_status  source_file_index  NumAcceptors  NumDonors     Energy  \
# ...

# %% [markdown]
# You can also control how tags are named using the constants in the ``oepandas_mae`` module. Here is how to get the full Maestro tag name.

# %%
import oepandas_mae as oemae

# %%
df2 = oepd.read_mae("../tests/assets/5.maegz", tags=oemae.TAG_ALL)
df2.head()
# Out:
#                                             Molecule          Title  \
# 0  <oechem.OEMol; proxy of <Swig Object of type '...        Aspirin
# 1  <oechem.OEMol; proxy of <Swig Object of type '...      Ibuprofen
# 2  <oechem.OEMol; proxy of <Swig Object of type '...  Acetaminophen
# 3  <oechem.OEMol; proxy of <Swig Object of type '...       Caffeine
# 4  <oechem.OEMol; proxy of <Swig Object of type '...       Diazepam
#
#    b_lp_Chiralities_Consistent  b_sd_chiral_flag  i_lp_mmshare_version  \
# 0                            1                 0                 73163
# 1                            1                 1                 73163
# 2                            1                 0                 73163
# 3                            1                 0                 73163
# 4                            1                 0                 73163
#
#    i_m_ct_format  i_m_ct_stereo_status  i_m_source_file_index  \
# 0              2                     1                      1
# ...

# %% [markdown]
# Note that ``oepandas-mae`` respects the data types specified by the Maestro data tags.

# %%
df2.dtypes
# Out:
# Molecule                       molecule
# Title                               str
# b_lp_Chiralities_Consistent       int64
# b_sd_chiral_flag                  int64
# i_lp_mmshare_version              int64
# i_m_ct_format                     int64
# i_m_ct_stereo_status              int64
# i_m_source_file_index             int64
# i_sd_NumAcceptors                 int64
# i_sd_NumDonors                    int64
# r_lp_Energy                     float64
# r_sd_MolWt                      float64
# s_lp_Force_Field                    str
# s_lp_Variant                        str
# s_m_source_file                     str
# s_st_Chirality_1                    str
# dtype: object
